# %% [markdown]
# # POLA TEU — Deep Models (LSTM, TCN, TFT)
#
# GPU on Colab recommended.

# %%
import torch, platform
print("Torch:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("Device count:", torch.cuda.device_count())
print("Python:", platform.python_version())
# Out:
# Torch: 2.10.0+cu128
# CUDA available: True
# Device count: 1
# Python: 3.12.12

# %%
import warnings
warnings.filterwarnings("ignore")
import os
os.environ["PYTHONWARNINGS"] = "ignore"

# %%
# !pip install "lightning>=2.2.0" "pytorch-forecasting>=1.1.0" -q
# !pip install lightgbm -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 853.6/853.6 kB 42.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 399.8/399.8 kB 25.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.8/159.8 kB 13.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.4/983.4 kB 63.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 857.3/857.3 kB 53.1 MB/s eta 0:00:00

# %%
from google.colab import drive
drive.mount('/content/drive')

WORK_DIR = "/content/drive/MyDrive/CS7643/Group Project"

import os, glob
os.chdir(WORK_DIR)
print("CWD:", os.getcwd())
print("Files:", glob.glob("*"))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# CWD: /content/drive/MyDrive/CS7643/Group Project
# Files: ['pola_teu.csv', 'metadata.yml', 'utils.py', '__pycache__', 'lightning_logs', 'train_lstm_tcn.py', 'checkpoints', 'train_tft.py', 'train_lgbm.py', 'visualize.py']

# %%
csv_path = os.path.join(WORK_DIR, "pola_teu.csv")
assert os.path.exists(csv_path), f"CSV not found: {csv_path}"
csv_path
# Out:
# '/content/drive/MyDrive/CS7643/Group Project/pola_teu.csv'

# %%
# !python train_lstm_tcn.py "{csv_path}" lstm --rolling
# Out:
# [20] train=75.61385 val=66.78059
# [40] train=2.63781 val=2.75267
# [60] train=0.70513 val=0.40612
# [80] train=0.94620 val=0.02448
# [100] train=0.78740 val=0.02884
# [120] train=0.82102 val=0.02810
# [140] train=0.69623 val=0.02343
# [160] train=0.58235 val=0.02267
# [180] train=0.69093 val=0.02001
# [200] train=0.76674 val=0.02087
# Origin 1/8 (t=37) done
# [20] train=83.53200 val=74.91122
# [40] train=3.16978 val=2.84280
# [60] train=1.09960 val=0.30420
# [80] train=0.73451 val=0.05173
# [100] train=0.90657 val=0.05998
# [120] train=0.61688 val=0.01677
# [140] train=0.64254 val=0.02607
# [160] train=0.71527 val=0.03663
# [180] train=0.71148 val=0.01916
# [200] train=0.55323 val=0.01693
# Origin 2/8 (t=38) done
# [20] train=2.58734 val=3.09279
# [40] train=0.85985 val=0.30689
# [60] train=0.84754 val=0.04749
# [80] train=0.98802 val=0.35057
# [100] train=0.58427 val=0.04324
# [120] train=0.38925 val=0.09014
# [140] train=0.66107 val=0.09139
# [160] train=0.63917 val=0.09219
# ...

# %%
# !python train_lstm_tcn.py "{csv_path}" tcn --rolling
# Out:
# [20] train=5.72671 val=5.39553
# [40] train=0.66235 val=0.66152
# [60] train=0.08795 val=0.07813
# [80] train=0.05962 val=0.05394
# [100] train=0.06445 val=0.05173
# [120] train=0.05311 val=0.04712
# [140] train=0.05516 val=0.04128
# [160] train=0.04974 val=0.04631
# [180] train=0.04231 val=0.03556
# [200] train=0.06433 val=0.03345
# Origin 1/8 (t=37) done
# [20] train=6.83352 val=5.32901
# [40] train=0.64142 val=0.20655
# [60] train=0.16284 val=0.10275
# [80] train=0.08088 val=0.06906
# [100] train=0.06746 val=0.02540
# [120] train=0.06459 val=0.02222
# [140] train=0.05053 val=0.02725
# [160] train=0.05057 val=0.01968
# [180] train=0.06161 val=0.02007
# [200] train=0.06225 val=0.02105
# Origin 2/8 (t=38) done
# [20] train=0.33684 val=0.26309
# [40] train=0.09287 val=0.11940
# [60] train=0.07621 val=0.12176
# [80] train=0.07363 val=0.04384
# [100] train=0.07571 val=0.06178
# [120] train=0.08192 val=0.05571
# [140] train=0.12017 val=0.03300
# [160] train=0.06309 val=0.01685
# ...

# %%
# !python train_tft.py "{csv_path}"
# Out:
# Seed set to 42
# Origin 1/8 (t=74, train up to idx 73)...
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# ┏━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃    ┃ Name                               ┃ Type      ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0  │ loss                               │ Quantile… │      0 │ train │     0 │
# ...

# %%
# !python train_lgbm.py "{csv_path}"
# Out:
# [Rolling-Origin] LightGBM (seed=42)
#  horizon    n            RMSE             MAE    MAPE(%)
#        1    8   49,341.781269   45,136.844816   6.263769
#        3    8   69,131.617857   58,598.474903   8.221751
#        6    8   84,480.884515   61,077.674600   8.703498
#       12    7   47,801.540635   45,656.065475   6.348634

# %%
# !python -W ignore visualize.py "{csv_path}" figures
# Out:
# Loading data …
# Running SARIMAX rolling-origin (this takes ~2 min) …
# Running LightGBM rolling-origin …
# Generating figures …
#   Saved: figures/fig1_mape_comparison.png
#   Saved: figures/fig2_forecast_vs_actual.png
#   Saved: figures/fig3_horizon_trend.png
#   Saved: figures/fig4_error_distribution.png
#
# All figures saved to: figures
